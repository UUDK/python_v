# %% [markdown]
# # Python advanced class
#
# ## Module 9, Test and Software Quality
#
# * Unittest and pytest
# * Logging
# * mypy
# * Pylint and flake8
# * Black

# %% [markdown]
# # Unittest and pytest
# # Logging
# # mypy
# # Pylint and flake8
# # Black
